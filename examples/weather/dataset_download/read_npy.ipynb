# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from datetime import datetime, timedelta
import pandas as pd

# %%
dir = "/datasets/hdf5_data_uvsp_swh_mwp_1/"

# %%
global_means = np.load(f'{dir}/stats/global_means.npy')
global_means
# Out:
# array([[[[-8.1173545e-01]],
#
#         [[-4.1325822e-01]],
#
#         [[ 9.7330766e+04]],
#
#         [[ 1.4292930e+00]],
#
#         [[ 6.4420772e+00]]]], dtype=float32)

# %%
global_stds = np.load(f'{dir}/stats/global_stds.npy')
global_stds
# Out:
# array([[[[ 0.08968098]],
#
#         [[ 0.0738481 ]],
#
#         [[11.249947  ]],
#
#         [[ 0.03767322]],
#
#         [[ 0.07305922]]]], dtype=float32)
